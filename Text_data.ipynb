# %% [markdown]
# <a href="https://colab.research.google.com/github/VEENA20221CCS0149/Data-Handling-and-Visualization/blob/main/Text_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# %%
text_data="Vinay Veena Akshya Dinesh Charan Murali Daddy Amma"
wordcloud=WordCloud(width=800,height=400,background_color="black").generate(text_data)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.show()
words=text_data.split()
word_counts=Counter(words)
plt.figure(figsize=(10,5))
plt.bar(word_counts.keys(),word_counts.values())
plt.title('Names')
plt.xlabel('words')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
